# %%
from Ladruno.core.model import Model

model = Model(
    path="/mnt/deadmanschest/pxpalacios/FD",
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
)

exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model
# find /mnt/deadmanschest/pxpalacios/CEREBRO/FRAMEMODELS/FrameModel -type d -user pxpalacios -exec chmod u+w {} \;

model = Model(
    # path="/mnt/deadmanschest/pxpalacios/TEST_ESMERALDA/01/",
    path="/mnt/leviathanchest/pxpalacios/04. PBD-V Conference 2026/05_tcl/00_base",
    # number_of_nodes=2,
    # ntasks=32,
    # max_tasks_per_node=32,
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
    archive_destination='/mnt/krakenschest/home/pxpalacios'
)

# exclude_nodes = [f"node{n}" for n in range(1,17)]
exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model
# find /mnt/deadmanschest/pxpalacios/CEREBRO/FRAMEMODELS/FrameModel -type d -user pxpalacios -exec chmod u+w {} \;

model = Model(
    # path="/mnt/deadmanschest/pxpalacios/TEST_ESMERALDA/01/",
    path="/mnt/krakenschest/home/pxpalacios/100_CompDSSI 2026/04_MODELS_DRM/drm_100_100_50_dx_5_0_dt_0_005/tcl_100_100_50_dx_5_0_dt_0_005",
    # number_of_nodes=2,
    # ntasks=32,
    # max_tasks_per_node=32,
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/opensees-14072025',
    archive_destination='/mnt/krakenschest/home/pxpalacios'
)

# exclude_nodes = [f"node{n}" for n in range(1,17)]
exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model
# find /mnt/deadmanschest/pxpalacios/CEREBRO/FRAMEMODELS/FrameModel -type d -user pxpalacios -exec chmod u+w {} \;

model = Model(
    # path="/mnt/deadmanschest/pxpalacios/TEST_ESMERALDA/01/",
    path="/mnt/krakenschest/home/pxpalacios/100_CompDSSI 2026/04_MODELS_DRM/drm_100_100_50_dx_7_5_dt_0_005/tcl_100_100_50_dx_7_5_0_dt_0_005",
    # number_of_nodes=2,
    # ntasks=32,
    # max_tasks_per_node=32,
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/opensees-14072025',
    archive_destination='/mnt/krakenschest/home/pxpalacios'
)

# exclude_nodes = [f"node{n}" for n in range(1,17)]
exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model
# find /mnt/deadmanschest/pxpalacios/CEREBRO/FRAMEMODELS/FrameModel -type d -user pxpalacios -exec chmod u+w {} \;

model = Model(
    # path="/mnt/deadmanschest/pxpalacios/TEST_ESMERALDA/01/",
    path="/mnt/krakenschest/home/pxpalacios/100_CompDSSI 2026/04_MODELS_DRM/drm_100_100_50_dx_10_0_dt_0_005/tcl_100_100_50_dx_10_0_dt_0_005",
    # number_of_nodes=2,
    # ntasks=32,
    # max_tasks_per_node=32,
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
    archive_destination='/mnt/krakenschest/home/pxpalacios'
)

# exclude_nodes = [f"node{n}" for n in range(1,17)]
exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
# from Ladruno.core.model import Model

# model = Model(
#     path="/mnt/deadmanschest/nmorabowen/Prueba_EX/",
#     # number_of_nodes=2,
#     # ntasks=32,
#     # max_tasks_per_node=32,
#     verbose=True,
#     opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
#     archive_destination='/mnt/krakenschest/home/pxpalacios'
# )

# exclude_nodes = [f"node{n}" for n in range(1,17)]
# print(exclude_nodes)

# model.submit(
#     exclude=exclude_nodes,
#     monitor_ram=False,
#     archive=False,
# )

# %% [markdown]
# # Chancador Viga Acople

# %%
from Ladruno.core.model import Model

model = Model(
    path="/mnt/leviathanchest/pxpalacios/STKO_CH/acople_CH_200",
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
)

exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model

model = Model(
    path="/mnt/leviathanchest/pxpalacios/STKO_CH/acople_V2_CH_200",
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
)

exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model

model = Model(
    path="/mnt/leviathanchest/pxpalacios/STKO_CH/STKO_RVT_EST001_COMPLETE_V2_002",
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
)

exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model

model = Model(
    path="/mnt/leviathanchest/pxpalacios/STKO_CH/STKO_RVT_EST001_COMPLETE_V2_003_3",
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
)

exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)

# %%
from Ladruno.core.model import Model

model = Model(
    path="/mnt/leviathanchest/pxpalacios/STKO_CH/_100",
    verbose=True,
    opensees_exe='/mnt/nfshare/bin/openseesmp_28102025',
)

exclude_nodes= None

model.submit(
    exclude=exclude_nodes,
    monitor_ram=False,
    archive=False,
)
# Out:
# 🚀 Submitting 10 model(s)
#
# [1/10] STKO_RVT_EST001_COMPLETE_V2_003_10mm_18mm
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Found 16 partitions, max index 15
# 📦 nodes=1, ntasks=16
# 📝 run.sh created (nodes=1, ntasks=16)
# 🚀 Job 142975 submitted
# [2/10] STKO_RVT_EST001_COMPLETE_V2_003_10mm_25mm
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Found 16 partitions, max index 15
# 📦 nodes=1, ntasks=16
# 📝 run.sh created (nodes=1, ntasks=16)
# 🚀 Job 142976 submitted
# [3/10] STKO_RVT_EST001_COMPLETE_V2_003_10mm_32mm
# ...
